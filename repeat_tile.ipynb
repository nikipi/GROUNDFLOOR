# %%
import numpy as np
arr=np.random.randn(5,2)

# %%
first,second,third=np.split(arr,[1,3])

# %%
first
# Out:
# array([[ 0.83771953, -0.31212898]])

# %%
second
# Out:
# array([[-0.89798592,  0.01764049],
#        [ 0.9081316 , -0.80843507]])

# %%
third
# Out:
# array([[ 1.1312557 ,  0.18039268],
#        [-0.90784035,  1.16796451]])

# %%
arr=np.arange(3)

# %%
arr.repeat(3)
# Out:
# array([0, 0, 0, 1, 1, 1, 2, 2, 2])

# %%
arr.repeat([2,3,4])
# Out:
# array([0, 0, 1, 1, 1, 2, 2, 2, 2])

# %%
arr=np.random.randn(2,2)

# %%
arr
# Out:
# array([[-0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  ]])

# %%
arr.repeat(2)
# Out:
# array([-0.85650062, -0.85650062,  0.45611645,  0.45611645, -1.98817182,
#        -1.98817182, -0.352389  , -0.352389  ])

# %%
arr.repeat(2,axis=0)
# Out:
# array([[-0.85650062,  0.45611645],
#        [-0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  ],
#        [-1.98817182, -0.352389  ]])

# %%
arr.repeat(2,axis=1)
# Out:
# array([[-0.85650062, -0.85650062,  0.45611645,  0.45611645],
#        [-1.98817182, -1.98817182, -0.352389  , -0.352389  ]])

# %%
np.tile(arr,2)
# Out:
# array([[-0.85650062,  0.45611645, -0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  , -1.98817182, -0.352389  ]])

# %%
np.tile(arr,(3,2))
# Out:
# array([[-0.85650062,  0.45611645, -0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  , -1.98817182, -0.352389  ],
#        [-0.85650062,  0.45611645, -0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  , -1.98817182, -0.352389  ],
#        [-0.85650062,  0.45611645, -0.85650062,  0.45611645],
#        [-1.98817182, -0.352389  , -1.98817182, -0.352389  ]])
