# %% [markdown]
# # Pandas Practice Diamonds

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import pandas as pd

df= pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
# print(diamonds.head(2))
# print(diamonds['cut'].head(2))

df['quality-color']=df['cut']+'-'+df['color']
print(df.head(2))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
#
#   quality-color
# 0       Ideal-E
# 1     Premium-E

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   carat          53940 non-null  float64
#  1   cut            53940 non-null  object
#  2   color          53940 non-null  object
#  3   clarity        53940 non-null  object
#  4   depth          53940 non-null  float64
#  5   table          53940 non-null  float64
#  6   price          53940 non-null  int64
#  7   x              53940 non-null  float64
#  8   y              53940 non-null  float64
#  9   z              53940 non-null  float64
#  10  quality-color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
# summarize only 'object' columns of the diamonds Dataframe.

df.describe(include=['object'])
# Out:
#           cut  color clarity quality-color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1       Ideal-G
# freq    21551  11292   13065          4884

# %%
# RENAME
df.rename(columns={'cut':'Cut','color':'Color'},inplace=True)
df.head()
# Out:
#    carat      Cut Color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality-color
# 0       Ideal-E
# 1     Premium-E
# 2        Good-E
# 3     Premium-I
# 4        Good-J

# %%
df.drop(['carat','depth','table'],axis=1)
# Out:
#              Cut Color clarity  price     x     y     z quality-color
# 0          Ideal     E     SI2    326  3.95  3.98  2.43       Ideal-E
# 1        Premium     E     SI1    326  3.89  3.84  2.31     Premium-E
# 2           Good     E     VS1    327  4.05  4.07  2.31        Good-E
# 3        Premium     I     VS2    334  4.20  4.23  2.63     Premium-I
# 4           Good     J     SI2    335  4.34  4.35  2.75        Good-J
# ...          ...   ...     ...    ...   ...   ...   ...           ...
# 53935      Ideal     D     SI1   2757  5.75  5.76  3.50       Ideal-D
# 53936       Good     D     SI1   2757  5.69  5.75  3.61        Good-D
# 53937  Very Good     D     SI1   2757  5.66  5.68  3.56   Very Good-D
# 53938    Premium     H     SI2   2757  6.15  6.12  3.74     Premium-H
# 53939      Ideal     D     SI2   2757  5.83  5.87  3.64       Ideal-D
#
# [53940 rows x 8 columns]

# %%
df.drop([0,2,4],axis=0)
# Out:
#        carat        Cut Color clarity  depth  table  price     x     y     z  \
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality-color
# 1         Premium-E
# ...

# %%
df['Cut'].sort_values(ascending=True)
# return as a series
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: Cut, Length: 53940, dtype: object

# %%
df['price'].sort_values(ascending=True)
# Out:
# 0          326
# 1          326
# 2          327
# 3          334
# 4          335
#          ...
# 27745    18803
# 27746    18804
# 27747    18806
# 27748    18818
# 27749    18823
# Name: price, Length: 53940, dtype: int64

# %%
df.sort_values('Cut',ascending=True)
# Out:
#        carat        Cut Color clarity  depth  table  price     x     y     z  \
# 3850    1.01       Fair     F     SI2   64.8   55.0   3477  6.37  6.26  4.10
# 51464   1.20       Fair     G      I1   66.6   57.0   2376  6.57  6.50  4.34
# 51466   0.90       Fair     G     SI2   65.4   57.0   2376  6.01  5.97  3.98
# 10237   1.26       Fair     D     SI2   64.5   59.0   4746  6.75  6.71  4.34
# 10760   1.01       Fair     E     SI1   69.5   55.0   4853  6.00  5.94  4.15
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 7402    0.33  Very Good     G     VS2   62.8   54.0    579  4.40  4.42  2.77
# 43101   0.57  Very Good     E     SI2   58.8   57.3   1384  5.42  5.46  3.21
# 16893   1.00  Very Good     G     VS2   62.2   58.0   6743  6.35  6.39  3.96
# 16898   1.00  Very Good     D     VS2   59.6   60.0   6745  6.52  6.57  3.90
# 21164   1.00  Very Good     E    VVS2   61.7   55.0   9324  6.38  6.42  3.95
#
#       quality-color
# 3850         Fair-F
# ...

# %%
df[df['carat']>0.3]
# Out:
#        carat        Cut Color clarity  depth  table  price     x     y     z  \
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 13      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 15      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 23      0.31  Very Good     J     SI1   59.4   62.0    353  4.39  4.43  2.62
# 24      0.31  Very Good     J     SI1   58.1   62.0    353  4.44  4.47  2.59
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality-color
# 4            Good-J
# ...

# %%
# find whether first 10 row's diamond has >0.3 carat

carat=[]
for w in df['carat']:
    if w>0.3:
        carat.append(True)
    else:
        carat.append(False)

print(carat[:10])
# Out:
# [False, False, False, False, True, False, False, False, False, False]

# %%
# find the details of the diamonds where length>5, width>5 and depth>5.
df[(df['x']>5) & (df['y']>5) & (df['z']>5)]
# Out:
#        carat        Cut Color clarity  depth  table  price     x      y  \
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04
#
#            z quality-color
# 11778   5.12        Fair-J
# 13002   5.36        Fair-J
# ...

# %%
good=['Premium','Ideal']
df[df['Cut'].isin(good)]
# Out:
#        carat      Cut Color clarity  depth  table  price     x     y     z  \
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality-color
# 0           Ideal-E
# 1         Premium-E
# ...

# %%
df.columns
# Out:
# Index(['carat', 'Cut', 'Color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'quality-color'],
#       dtype='object')

# %%
#Read only a subset of 5 rows from diamonds DataFrame
url='https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv'
small=pd.read_csv(url,nrows=5)
small
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9     65    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4     58    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3     58    335  4.34  4.35  2.75

# %%
for index,row in small.iterrows():
    print(index)
    print(row)
# Out:
# 0
# carat       0.23
# cut        Ideal
# color          E
# clarity      SI2
# depth       61.5
# table         55
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object
# 1
# carat         0.21
# cut        Premium
# color            E
# clarity        SI1
# depth         59.8
# table           61
# price          326
# x             3.89
# y             3.84
# z             2.31
# Name: 1, dtype: object
# 2
# carat      0.23
# cut        Good
# color         E
# clarity     VS1
# depth      56.9
# table        65
# price       327
# x          4.05
# y          4.07
# z          2.31
# Name: 2, dtype: object
# 3
# carat         0.29
# cut        Premium
# color            I
# clarity        VS2
# depth         62.4
# table           58
# price          334
# x              4.2
# y             4.23
# z             2.63
# Name: 3, dtype: object
# 4
# carat      0.31
# cut        Good
# color         J
# clarity     SI2
# depth      63.3
# ...

# %%
#Iterate through diamonds DataFrame
for index, row in small.iterrows():
    print(index)
    print(row.cut)
    print(row.price)
# Out:
# 0
# Ideal
# 326
# 1
# Premium
# 326
# 2
# Good
# 327
# 3
# Premium
# 334
# 4
# Good
# 335

# %%
import numpy as np
df.select_dtypes(include=[np.number])
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
df.select_dtypes(include=[np.number]).dtypes
# Out:
# carat    float64
# depth    float64
# table    float64
# price      int64
# x        float64
# y        float64
# z        float64
# dtype: object

# %%
df.describe(include=['object','float64'])
# Out:
#                carat    Cut  Color clarity         depth         table  \
# count   53940.000000  53940  53940   53940  53940.000000  53940.000000
# unique           NaN      5      7       8           NaN           NaN
# top              NaN  Ideal      G     SI1           NaN           NaN
# freq             NaN  21551  11292   13065           NaN           NaN
# mean        0.797940    NaN    NaN     NaN     61.749405     57.457184
# std         0.474011    NaN    NaN     NaN      1.432621      2.234491
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         5.010000    NaN    NaN     NaN     79.000000     95.000000
#
#                    x             y             z quality-color
# ...

# %%
df.mean()  # the mean of each numeric column
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
df.groupby('Cut')['price'].mean()
# Out:
# Cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
df.groupby('Cut').price.mean()
# Out:
# Cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
df.groupby('Cut').price.agg(['count','min','max'])
# Out:
#            count  min    max
# Cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %%
df.groupby('Cut').mean().plot(kind='bar')

# %%
# normalize=True

df['Cut'].value_counts(normalize=True) *100   #Display percentages of each value of cut series occurs in diamonds DataFrame
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: Cut, dtype: float64

# %%
df['Cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['Cut'].nunique()
# Out:
# 5

# %%
# compute a cross-tabulation of two Series in diamonds DataFrame.
pd.crosstab(df.Cut,df.Color)
# Out:
# Color         D     E     F     G     H     I    J
# Cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
df['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
df['carat'].hist()

# %%
df['Cut'].value_counts().plot(kind='bar')

# %%
df.isnull().sum()
# Out:
# carat            0
# Cut              0
# Color            0
# clarity          0
# depth            0
# table            0
# price            0
# x                0
# y                0
# z                0
# quality-color    0
# dtype: int64

# %%
df.set_index('Color',inplace=True)

# %%
df
# Out:
#        carat        Cut clarity  depth  table  price     x     y     z  \
# Color
# E       0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# E       0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# E       0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# I       0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# J       0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...     ...    ...    ...    ...   ...   ...   ...
# D       0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# D       0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# D       0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# H       0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# D       0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality-color
# Color
# E           Ideal-E
# E         Premium-E
# E            Good-E
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#       Color  carat        Cut clarity  depth  table  price     x     y     z  \
# 0         E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality-color
# 0           Ideal-E
# ...

# %%
df['xyz']=df.x*df.y*df.z

# %%
df.groupby('Cut')['xyz'].mean()
# Out:
# Cut
# Fair         164.950549
# Good         136.257267
# Ideal        115.394912
# Premium      145.052128
# Very Good    130.999722
# Name: xyz, dtype: float64

# %%
df.loc[df['Cut']=='Premium','Color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: Color, Length: 13791, dtype: object

# %%
df.iloc[[0,1],[1,3]]
# Out:
#    carat clarity
# 0   0.23     SI2
# 1   0.21     SI1

# %%
df.memory_usage(deep=True)
# Out:
# Index                128
# Color            3560040
# carat             431520
# Cut              4985810
# clarity          3242590
# depth             431520
# table             431520
# price             431520
# x                 431520
# y                 431520
# z                 431520
# quality-color    3521554
# xyz               431520
# dtype: int64

# %%
df.sample(n=5)
# Out:
#       Color  carat      Cut clarity  depth  table  price     x     y     z  \
# 28860     F   0.30    Ideal    VVS2   62.3   54.0    684  4.32  4.35  2.70
# 35739     D   0.30  Premium     VS2   61.1   59.0    911  4.31  4.26  2.62
# 14400     F   1.01     Good     VS2   63.1   59.0   5817  6.31  6.37  4.00
# 5461      I   1.17     Fair     SI2   59.2   68.0   3833  6.91  6.84  4.07
# 44783     D   0.51    Ideal     VS2   61.8   54.0   1623  5.12  5.17  3.18
#
#       quality-color         xyz
# 28860       Ideal-F   50.738400
# 35739     Premium-D   48.104772
# 14400        Good-F  160.778800
# 5461         Fair-I  192.366108
# 44783       Ideal-D   84.175872

# %%
#Get sample 75% of the diamonds DataFrame's rows 
#without replacement and store the remaining 25% of the rows in another DataFrame


train=df.sample(frac=0.75,random_state=99)
test=df.loc[~df.index.isin(train.index),:]

train.shape
test.shape
# Out:
# (13485, 12)

# %%
df['price'].duplicated().sum()
# Out:
# 42338
